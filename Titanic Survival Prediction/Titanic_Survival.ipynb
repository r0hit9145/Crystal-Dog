# %% [markdown]
# <h1> Titanic Survival Prediction</h1>

# %%
# imported important libraries
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Titanic_Survival= pd.read_csv("Titanic-Dataset.csv")

# %%
Titanic_Survival
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # This is help see full dataSets

# %%
print(Titanic_Survival.to_string()) #optional
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked  family
# 0              1         0       3                                                             Braund, Mr. Owen Harris    male  22.00      1      0           A/5 21171    7.2500              NaN        S       1
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0            PC 17599   71.2833              C85        C       1
# 2              3         1       3                                                              Heikkinen, Miss. Laina  female  26.00      0      0    STON/O2. 3101282    7.9250              NaN        S       0
# ...

# %%
Titanic_Survival.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  family       891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
# test.info()

# %% [markdown]
# Until and unless you're not sure about data done doesn' t include it.

# %%
# Droped out the unnecessary column

# %%
# so, droped cabin from our datsets
Titanic_Survival.drop(columns= ['Cabin'], inplace= True)

# %%
# Now checked cabin exitst or not

# %%
Titanic_Survival.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
#  11  family       891 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %% [markdown]
# # <h1> One more way to check isnull count sum of all it.</h1>

# %%
# checked whether is null or not ?
Titanic_Survival.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# family           0
# dtype: int64

# %% [markdown]
# <h1>first approach should be instead of dropping, fill up firstly.

# %%
Titanic_Survival['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# fill 2 na values in embarked

# %%
Titanic_Survival["Embarked"].fillna('S', inplace=True)
Titanic_Survival
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic_Survival['Embarked'].value_counts()
Emp= Titanic_Survival['Embarked']

# %% [markdown]
# <h1>Make a Histogram plot based on Embarked</h1>

# %%
plt.hist(Emp, color="purple")
plt.xlabel("Categories")
# plt.ylabel("Frequency of coresponding of categories")
plt.show()

# %%
# whether missing values or not -> Embarked
Titanic_Survival.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# family           0
# dtype: int64

# %%
# fillna('?')

# %%
Titanic_Survival
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# (177/891)*100 , isn't regenable to delete age column -> that has 19% data

# %% [markdown]
# <h1> histogram of  age data (Practice set-1)</h1>

# %%
age_Data=Titanic_Survival['Age']

# %%
# plotting a histogram plot -> optional

# %%
plt.hist(age_Data, edgecolor="skyblue")
plt.xlabel("Age")
plt.title("Histogram-> ages")
# plt.ylabel("Frequency of ages")      #please make sure brackets during plotting the plot

plt.show()

# plt.hist(age_Data, xlab="Age", ylab="Frequency of age", col="purple")

# %% [markdown]
# <!-- Optional(for practice purpose) -->

# %%
                                 #     LOW                +                                    High                    total_values

# %%
Tc_Age= np.random.randint(Titanic_Survival['Age'].mean() - Titanic_Survival['Age'].std(), Titanic_Survival['Age'].mean() + Titanic_Survival['Age'].std(),  177)

# %%
# printed result part
Tc_Age
# Out:
# array([29, 19, 35, 26, 20, 43, 28, 39, 17, 34, 22, 37, 19, 27, 27, 24, 16,
#        28, 33, 37, 23, 33, 24, 23, 26, 22, 20, 36, 42, 29, 43, 43, 43, 23,
#        15, 15, 26, 29, 40, 16, 36, 40, 30, 37, 43, 21, 23, 31, 19, 15, 27,
#        18, 35, 18, 21, 24, 36, 43, 42, 34, 32, 33, 23, 21, 21, 22, 18, 39,
#        40, 31, 38, 15, 34, 17, 41, 29, 42, 34, 32, 17, 29, 26, 29, 29, 22,
#        15, 42, 26, 22, 27, 31, 20, 17, 24, 22, 27, 31, 32, 25, 15, 15, 19,
#        30, 25, 33, 33, 16, 33, 19, 15, 21, 18, 26, 21, 41, 15, 22, 16, 35,
#        31, 24, 25, 36, 18, 25, 30, 17, 22, 36, 31, 20, 40, 25, 15, 25, 20,
#        22, 35, 20, 25, 25, 42, 39, 32, 17, 30, 21, 23, 27, 25, 38, 42, 26,
#        18, 37, 36, 40, 29, 39, 33, 34, 32, 18, 28, 16, 35, 18, 40, 28, 40,
#        31, 27, 32, 37, 32, 43, 41])

# %%
Titanic_Survival['Age'].isnull().shape
# Out:
# (891,)

# %%
Titanic_Survival.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
#  11  family       891 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
# Check it whether true or not -> null or not null
Titanic_Survival['Age'].isnull().shape
# Out:
# (891,)

# %%
# mapping

# %%
Titanic_Survival['Age'][Titanic_Survival['Age'].isnull()] = Tc_Age
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8604\2723043128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Titanic_Survival['Age'][Titanic_Survival['Age'].isnull()] = Tc_Age

# %%
# that is what, we would to find out.

# %%
# Result-> is null or not
Titanic_Survival.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# family         0
# dtype: int64

# %% [markdown]
# There is not any null values till now.

# %% [markdown]
# <h2>                                                          EDA</h2>

# %%
Titanic_Survival[Titanic_Survival['Pclass']==1] ['Survived'].value_counts()   #lived
# Out:
# Survived
# 1    136
# 0     80
# Name: count, dtype: int64

# %%
# Group by

# %%
# let's analysis in 2 catogories

#Pclass -> 1st, 2st and 3st
#Sex -> female and male
#Embarked -> S, C and

# %%
# we can only groupby at a time one but not more than 1 inside the group by(????)

# %%
# Pclass ?
Titanic_Survival.groupby(['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# Pclass <br>
# 1    0.629630 <br>
# 2    0.472826<br>
# 3    0.242363<br>
# Name: Survived, dtype: float64<be> <be>
#
# <h3>
#     We can predict who would be survived more in which three categories
# </h3>

# %%
# Sex ?

# %%
Titanic_Survival.groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Embarked ?

# %%
Titanic_Survival.groupby(['Embarked'])['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64

# %%
# my testing or analysis

# %%
# Titanic_Survival[Titanic_Survival['Embarked']== 'S']['Age'].value_counts --> awaiting

# %%
#Age ?

# %% [markdown]
# <B>Condition: there are no any missing values exist.</b>

# %%
sns.distplot(Titanic_Survival['Age'][Titanic_Survival['Survived']==0])
sns.distplot(Titanic_Survival['Age'][Titanic_Survival['Survived']==1])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8604\1647870839.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Titanic_Survival['Age'][Titanic_Survival['Survived']==0])
# C:\Users\lenovo\AnacondaFolder\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8604\1647870839.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
# Fare -> there is co-relation between them

# %%
sns.distplot(Titanic_Survival['Fare'][Titanic_Survival['Survived']==0])
sns.distplot(Titanic_Survival['Fare'][Titanic_Survival['Survived']==1])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8604\629401405.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Titanic_Survival['Fare'][Titanic_Survival['Survived']==0])
# C:\Users\lenovo\AnacondaFolder\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8604\629401405.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
# checked again null

# %%
Titanic_Survival.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# family         0
# dtype: int64

# %%
# we gonna remove 'Ticket'

# %%
Titanic_Survival.drop(columns=['Ticket'], inplace=True)

# %%
# printed once again to check it

# %%
Titanic_Survival
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# more analysis about it, adding two columns -> sibsp + parch into one family

# %%
# new column created
Titanic_Survival['FamilyNew'] = Titanic_Survival['SibSp'] + Titanic_Survival['Parch'] +1  #why +1? -> itself also added to them

# %%
Titanic_Survival
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h4> Analysis 'family' -> category or numerical ?

# %%
# let's check
Titanic_Survival['FamilyNew'].value_counts() #that's why categorical data
# Out:
# FamilyNew
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64

# %%
Titanic_Survival.groupby(['FamilyNew'])['Survived'].mean()
# Out:
# FamilyNew
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# <h3> Optional part:</h3>

# %%
sns.displot(Titanic_Survival['FamilyNew'][Titanic_Survival['Survived']==1]) #lived
sns.displot(Titanic_Survival['FamilyNew'][Titanic_Survival["Survived"]==0]) #died
# Out:
# C:\Users\lenovo\AnacondaFolder\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\AnacondaFolder\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <b>Based on these values, it is not possible to predict these 10 values so that we just making three categories </b>
# 1. along<br>
# 2. medium<br>
# 3. Large
#
# so we're going to make new col= FamilySize based on these three categories

# %%
def familyCategory(number):
    if number==1:
        return "Along"
    elif number >=1 and number<5:
        return 'Medium'
    else:
        return "Large"

# %% [raw]
# apply() <----- Pandas

# %%
Titanic_Survival["Family_Size"]= Titanic_Survival["FamilyNew"].apply(familyCategory)

# %%
Titanic_Survival.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  family  FamilyNew Family_Size
# 0      0   7.2500        S       1          2      Medium
# 1      0  71.2833        C       1          2      Medium
# 2      0   7.9250        S       0          1       Along
# 3      0  53.1000        S       1          2      Medium
# ...

# %% [markdown]
# Think about the columns sibsp, parch and family, they are needed or not?
#
# absulutely not-> so you may remove to them.

# %% [markdown]
# <b>using drop method</b>

# %%
Titanic_Survival.drop(columns=['SibSp', 'Parch', 'family'], inplace=True)

# %%
# check it?

# %%
Titanic_Survival
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ...

# %%
# let's check it its shape

# %%
Titanic_Survival.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# FamilyNew      0
# Family_Size    0
# dtype: int64

# %%
# let's see its shape

# %%
print(Titanic_Survival.shape)
# Out:
# (891, 10)

# %%
# check it once again

# %%
Titanic_Survival.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# FamilyNew      0
# Family_Size    0
# dtype: int64

# %%
# it would to good approach before deleting any columns to sove in a variable, it might be needed

# %%
# saved it before deleting it.
PassengerId= Titanic_Survival['PassengerId'].values
Name= Titanic_Survival['Name'].values

# %%
PassengerId.sum()
# Out:
# 397386

# %%
# now, you can drop them

# %%
Titanic_Survival.drop(columns= ['Name', "PassengerId", "FamilyNew"], inplace = True)

# %%
Titanic_Survival.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# Family_Size    0
# dtype: int64

# %%
# Now what we can predict to it? -> within algorithem

# %% [markdown]
# So 4 columns-> Pclass, Sex, Embarked and Family_Size -> categorical data
# <br><br>
# so, we can't predict to them, we would convert it into firstly numerical one.

# %% [markdown]
# <b> How to convent into numerical data?

# %% [markdown]
# <b>Label encoding is a technique used in machine learning to convert categorical data into numerical values so that algorithms can process it. In label encoding, each unique category value is assigned an integer number.
#
# Label encoding is a technique used in machine learning to convert categorical data into numerical values so that algorithms can process it. In label encoding, each unique category value is assigned an integer number.
#
# Here's a more detailed explanation:
#
# ### Why Use Label Encoding?
#
# Machine learning algorithms typically require numerical input and output variables. Categorical data, which represent discrete values or categories (such as "red," "blue," "green"), need to be transformed into a numerical format for the algorithm to make sense of it. Label encoding is one of the simplest ways to perform this transformation.
#
# ### How Label Encoding Works
#
# 1. **Identify the categorical feature**: Determine which feature(s) in your dataset contain categorical data.
# 2. **Assign an integer to each unique category**: Each unique category value is assigned a distinct integer. For example, for a "Color" feature with categories ["red", "blue", "green"], the label encoding might be:
#     - "red" -> 0
#     - "blue" -> 1
#     - "green" -> 2
#
# ### Example
#
# Consider a dataset with a single categorical feature, "Color":
#
# | Color |
# |-------|
# | red   |
# | blue  |
# | green |
# | blue  |
# | red   |
#
# After label encoding, the dataset would look like this:
#
# | Color |
# |-------|
# | 0     |
# | 1     |
# | 2     |
# | 1     |
# | 0     |
#
# ### Advantages
#
# - **Simplicity**: It is straightforward to implement and understand.
# - **Efficiency**: Uses minimal computational resources.
#
# ### Disadvantages
#
# - **Ordinal Nature**: Label encoding imposes an ordinal relationship between the categories, which might not always be appropriate. For instance, in the example above, it implies that "red" < "blue" < "green," which might not be meaningful.
# - **Non-uniqueness**: Some machine learning algorithms can misinterpret the encoded values as having a specific order or magnitude, which can lead to inaccurate results.
#
# ### Alternatives
#
# To avoid the ordinal implications of label encoding, other encoding methods such as **one-hot encoding** can be used, where each category is represented by a binary vector.
#
# ### Implementation in Python
#
# Here’s a basic implementation using `sklearn`:
#
# ```python
# from sklearn.preprocessing import LabelEncoder
#
# # Example data
# data = ['red', 'blue', 'green', 'blue', 'red']
#
# # Initialize label encoder
# label_encoder = LabelEncoder()
#
# # Fit and transform the data
# encoded_data = label_encoder.fit_transform(data)
#
# print(encoded_data)
# ```
#
# This will output:
#
# ```
# [0 1 2 1 0]
# ```
#
# Label encoding is a useful preprocessing step for many machine learning tasks, but it's important to understand when it's appropriate and when other methods might be more suitable.</b>

# %%
Titanic_Survival.shape
# Out:
# (891, 7)

# %%
Titanic_Survival= pd.get_dummies(Titanic_Survival, columns= ['Pclass', 'Sex', 'Embarked', 'Family_Size'], drop_first= True)

# %%
Titanic_Survival
# Out:
#      Survived   Age     Fare  Pclass_2  Pclass_3  Sex_male  Embarked_Q  \
# 0           0  22.0   7.2500     False      True      True       False
# 1           1  38.0  71.2833     False     False     False       False
# 2           1  26.0   7.9250     False      True     False       False
# 3           1  35.0  53.1000     False     False     False       False
# 4           0  35.0   8.0500     False      True      True       False
# ..        ...   ...      ...       ...       ...       ...         ...
# 886         0  27.0  13.0000      True     False      True       False
# 887         1  19.0  30.0000     False     False     False       False
# 888         0  41.0  23.4500     False      True     False       False
# 889         1  26.0  30.0000     False     False      True       False
# 890         0  32.0   7.7500     False      True      True        True
#
#      Embarked_S  Family_Size_Large  Family_Size_Medium
# 0          True              False                True
# ...

# %%
Titanic_Survival.shape
# Out:
# (891, 10)

# %% [markdown]
# <h3>The iloc function in pandas is used to select data by position or index. It allows you to access a group of rows and columns in a DataFrame using integer-based indexing.</h3>

# %%
X = Titanic_Survival.iloc[:, 1:].values
y = Titanic_Survival.iloc[:, 0].values

# %% [markdown]
# <h5>scikit-learn, often abbreviated as sklearn, is a widely-used open-source machine learning library in Python.<br> It provides a simple and efficient set of tools for data mining and data analysis. Here's a short overview:</h5> <br>
# <h3>Research and Development: </h3><br>
# Researchers and practitioners use scikit-learn for developing and experimenting with machine learning models, thanks to its extensive collection of algorithms and tools.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()

# %%
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = classifier.predict(X_test)

# %% [markdown]
# <h1>Finally calculating accuracy Scores<h1>

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_predict, y_test)
# Out:
# 0.8100558659217877
